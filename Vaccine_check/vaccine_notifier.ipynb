# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from bs4 import BeautifulSoup
import requests
from datetime import date
import json

# %%
pincode = 110001

# %%
today = date.today()
today.day
# Out:
# 4

# %%
URL = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByPin?pincode="+str(pincode)+"&date=04-05-2021" #need to change the date here to take the current date from the system

page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
data = soup.text

# %%
data
# Out:
# '{"centers":[{"center_id":662447,"name":"ICGS Delhi","address":"MI Room, National Stadium Complex, New Delhi, 110001","state_name":"Delhi","district_name":"New Delhi","block_name":"Not Applicable","pincode":110001,"lat":28,"long":77,"from":"09:00:00","to":"17:00:00","fee_type":"Free","sessions":[{"session_id":"056423a7-4c71-49ae-b91e-6e09086c3076","date":"04-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"b7440b34-cafe-4fe4-8792-75b255e0eaae","date":"05-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"29f24327-baee-4fcf-b69b-870995de00f5","date":"06-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"1f7b65da-6952-4ee0-aca0-1d5ef62847f8","date":"07-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"fdfcdde1-cde9-479d-89b2-ea1ccca799fa","date":"08-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"4e2b7594-d2e1-4d62-ba2d-caf1e1c819be","date":"10-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]}]},{"center_id":563193,"name":"LHMC CVC 1","address":"C- 604, Connaught Circus, Bangla Sahib Rd, DIZ Area, Connaught Place, New Delhi","state_name":"Delhi","district_name":"New Delhi","block_name":"Central Delhi","pincode":110001,"lat":28,"long":77,"from":"09:00:00","to":"17:00:00","fee_type":"Free","sessions":[{"session_id":"d2d19814-9dcb-4c85-ab6e-156c1d2af31d","date":"05-05-2021","available_capacity":12,"min_age_limit":45,"vaccine":"COVAXIN","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"2b6bb751-e69c-45fb-add9-1e2ee982d9eb","date":"06-05-2021","available_capacity":73,"min_age_limit":45,"vaccine":"COVAXIN","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"5beb5a1c-c154-4ec9-be8a-423375104c9c","date":"07-05-2021","available_capacity":56,"min_age_limit":45,"vaccine":"COVAXIN","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"178ff237-4664-4764-8d0d-1ec190414c32","date":"08-05-2021","available_capacity":38,"min_age_limit":45,"vaccine":"COVAXIN","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"59cd8fe5-01f1-4750-ba53-aacbad43c93e","date":"10-05-2021","available_capacity":70,"min_age_limit":45,"vaccine":"COVAXIN","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]}]},{"center_id":605450,"name":"Supreme Court Complex","address":"Tilak Marg, New Delhi-110001","state_name":"Delhi","district_name":"New Delhi","block_name":"Not Applicable","pincode":110001,"lat":28,"long":77,"from":"09:00:00","to":"17:00:00","fee_type":"Free","sessions":[{"session_id":"b1ebb3ba-edbb-41a1-896f-674baaf94ff5","date":"05-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]},{"session_id":"18aa1113-7e26-4599-957e-87f41c8661c7","date":"06-05-2021","available_capacity":0,"min_age_limit":45,"vaccine":"COVISHIELD","slots":["09:00AM-11:00AM","11:00AM-01:00PM","01:00PM-03:00PM","03:00PM-05:00PM"]}]},{"center_id":563206,"name":"RML Site 1","address":"Baba Kharak Singh Marg","state_name":"Delhi","district_name":"New Delhi","block_name":"Central Delhi","pincode":110001,"lat":28,"long":77,"from":"09:00:00","to":"17:00:00","fee_type":"Free","sessions":[ ...

# %%
d = json.loads(data)

# %%
d["centers"]
# Out:
# [{'center_id': 662447,
#   'name': 'ICGS Delhi',
#   'address': 'MI Room, National Stadium Complex, New Delhi, 110001',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '056423a7-4c71-49ae-b91e-6e09086c3076',
#     'date': '04-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'b7440b34-cafe-4fe4-8792-75b255e0eaae',
#     'date': '05-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '29f24327-baee-4fcf-b69b-870995de00f5',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '1f7b65da-6952-4ee0-aca0-1d5ef62847f8',
#     'date': '07-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'fdfcdde1-cde9-479d-89b2-ea1ccca799fa',
#     'date': '08-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '4e2b7594-d2e1-4d62-ba2d-caf1e1c819be',
#     'date': '10-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 563193,
#   'name': 'LHMC CVC 1',
#   'address': 'C- 604, Connaught Circus, Bangla Sahib Rd, DIZ Area, Connaught Place, New Delhi',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Central Delhi',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': 'd2d19814-9dcb-4c85-ab6e-156c1d2af31d',
#     'date': '05-05-2021',
#     'available_capacity': 12,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '2b6bb751-e69c-45fb-add9-1e2ee982d9eb',
#     'date': '06-05-2021',
#     'available_capacity': 73,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '5beb5a1c-c154-4ec9-be8a-423375104c9c',
#     'date': '07-05-2021',
#     'available_capacity': 56,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '178ff237-4664-4764-8d0d-1ec190414c32',
#     'date': '08-05-2021',
#     'available_capacity': 38,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '59cd8fe5-01f1-4750-ba53-aacbad43c93e',
#     'date': '10-05-2021',
#     'available_capacity': 70,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 605450,
#   'name': 'Supreme Court Complex',
#   'address': 'Tilak Marg, New Delhi-110001',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': 'b1ebb3ba-edbb-41a1-896f-674baaf94ff5',
#     'date': '05-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '18aa1113-7e26-4599-957e-87f41c8661c7',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 563206,
#   'name': 'RML Site 1',
#   'address': 'Baba Kharak Singh Marg',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Central Delhi',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': 'fb40c236-da36-4c5d-ba83-f540a9737f14',
#     'date': '05-05-2021',
#     'available_capacity': 9,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '9b22a934-c6ac-4d0a-aaf0-2bacd5d4dc44',
#     'date': '06-05-2021',
#     'available_capacity': 45,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '1d15e297-4b4f-4cc5-851c-6a88018b5818',
#     'date': '07-05-2021',
#     'available_capacity': 44,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '30297efa-fd5b-49bd-8278-0a9ef05a85ba',
#     'date': '08-05-2021',
#     'available_capacity': 46,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'f23457fe-290d-42a8-bd46-33c4173c9142',
#     'date': '10-05-2021',
#     'available_capacity': 36,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 576584,
#   'name': 'LHMC CVC 2',
#   'address': 'C- 604, Connaught Circus, Bangla Sahib Rd, DIZ Area, Connaught Place, New Delhi',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Central Delhi',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': 'f918daa4-ba23-444f-8485-1be81f3d6099',
#     'date': '05-05-2021',
#     'available_capacity': 76,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '12a245a5-c444-4d29-a71b-b84d35495216',
#     'date': '06-05-2021',
#     'available_capacity': 97,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'f78c4006-f52d-454a-bd48-dc9c1e55354e',
#     'date': '07-05-2021',
#     'available_capacity': 96,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '1f11a5c1-62c9-4ea7-b902-e3b98ce75132',
#     'date': '08-05-2021',
#     'available_capacity': 92,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'b017170c-465d-4c5d-9a2b-e86bb81b60a8',
#     'date': '10-05-2021',
#     'available_capacity': 90,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 584471,
#   'name': 'RML Site 3',
#   'address': 'BKS Marg,CP,New Delhi',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Central Delhi',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': 'a551d089-9de6-42ba-92b6-ecb7c3423475',
#     'date': '05-05-2021',
#     'available_capacity': 71,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'aa47a88f-4b38-40ad-8bdb-53c1bf1752f9',
#     'date': '06-05-2021',
#     'available_capacity': 90,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'db3efffd-6c97-42c0-9357-781228036eae',
#     'date': '07-05-2021',
#     'available_capacity': 86,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '622172f5-e273-436e-a70d-564891371d3c',
#     'date': '08-05-2021',
#     'available_capacity': 83,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'dc1c0965-2222-4692-a5c6-1b891cde5d22',
#     'date': '10-05-2021',
#     'available_capacity': 90,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 580925,
#   'name': 'RML Site 2',
#   'address': 'BKS Marg,CP,New Delhi',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Central Delhi',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '431a0824-ee61-4735-86f0-07ff973b8bef',
#     'date': '05-05-2021',
#     'available_capacity': 73,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'bf4f4a12-aa5a-402b-973a-c71192de6ed5',
#     'date': '06-05-2021',
#     'available_capacity': 85,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '67980791-7169-499b-bd78-408eccf21b0b',
#     'date': '07-05-2021',
#     'available_capacity': 78,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '7c24edf1-7a00-4d77-ae3d-86f1fbc820c4',
#     'date': '08-05-2021',
#     'available_capacity': 69,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '8ff52a27-b62d-439b-9769-d083aa850483',
#     'date': '10-05-2021',
#     'available_capacity': 65,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 563048,
#   'name': 'G.B.Pant Hospital DH SITE 2',
#   'address': 'J.L.N Marg, Delhi Gate, New Delhi 110001',
#   'state_name': 'Delhi',
#   'district_name': 'Central Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '21:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': 'cadf7332-280a-4176-9411-f1be64e3c0e8',
#     'date': '05-05-2021',
#     'available_capacity': 184,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-12:00PM',
#      '12:00PM-03:00PM',
#      '03:00PM-06:00PM',
#      '06:00PM-09:00PM']},
#    {'session_id': 'b3412c54-8c5c-4174-ba6f-38a49c3c793a',
#     'date': '06-05-2021',
#     'available_capacity': 195,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-12:00PM',
#      '12:00PM-03:00PM',
#      '03:00PM-06:00PM',
#      '06:00PM-09:00PM']},
#    {'session_id': 'bcde5cca-3f7e-45d9-9420-c8008872a0d7',
#     'date': '07-05-2021',
#     'available_capacity': 198,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-12:00PM',
#      '12:00PM-03:00PM',
#      '03:00PM-06:00PM',
#      '06:00PM-09:00PM']},
#    {'session_id': '403428b6-ac3b-421e-a96f-aeccb76d47ab',
#     'date': '08-05-2021',
#     'available_capacity': 187,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-12:00PM',
#      '12:00PM-03:00PM',
#      '03:00PM-06:00PM',
#      '06:00PM-09:00PM']},
#    {'session_id': '98a2aca9-881b-493f-8798-5ee8bd03aa5c',
#     'date': '10-05-2021',
#     'available_capacity': 194,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-12:00PM',
#      '12:00PM-03:00PM',
#      '03:00PM-06:00PM',
#      '06:00PM-09:00PM']}]},
#  {'center_id': 632961,
#   'name': 'Rouse Avenue Court',
#   'address': 'Rouse Avenue Court Complex',
#   'state_name': 'Delhi',
#   'district_name': 'Central Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '1ef31dcc-0e86-4ec8-9f4e-897e56f13716',
#     'date': '05-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '8936c1d2-edd6-493b-b13b-64caae0c9edf',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '02a1382a-9f8c-478f-bb5f-02b8e640f65c',
#     'date': '07-05-2021',
#     'available_capacity': 2,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '95611016-edd9-46e2-b9ea-06ea9095f101',
#     'date': '08-05-2021',
#     'available_capacity': 13,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '8e4c826c-eda6-4749-b692-96d7e774edea',
#     'date': '10-05-2021',
#     'available_capacity': 2,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 679800,
#   'name': 'MHA North Block',
#   'address': 'North Block, Central Secretariat, New Delhi, Delhi 110001',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Central Delhi',
#   'pincode': 110001,
#   'lat': 0,
#   'long': 0,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '0d9eebca-ebf0-494e-9f41-cc45c31cc578',
#     'date': '05-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'a243e443-07bc-4235-8d8b-5a638df67e0d',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '156cbfaa-03cd-414a-9ba5-8d3123983390',
#     'date': '07-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '9f3b67fd-7e45-4c82-bbeb-c632f8958e14',
#     'date': '08-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVAXIN',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 613502,
#   'name': 'Parliament House',
#   'address': 'Sansad Marg,anpath, Connaught Place, New Delhi',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 0,
#   'long': 0,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': 'da34e222-7560-414d-ad38-46b1cdf41768',
#     'date': '05-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '68940758-68c9-4aa7-92a3-50a7f716a268',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '8ad7aefa-6e65-4e19-9bbe-33c6147c73cd',
#     'date': '07-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'a740e7cd-a6bf-468f-ad22-339fac8774f0',
#     'date': '08-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '7b463b55-cf01-46c8-8d9c-53ab3e7d96d1',
#     'date': '10-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 8817,
#   'name': 'MCW Shishu Kalyan Kendra PHC',
#   'address': 'Shaheed Bhagat Singh Road Poly Clinic',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '2accbb28-f6f0-4653-99f9-81c8c7bf7f0c',
#     'date': '06-05-2021',
#     'available_capacity': 35,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '05fc44ce-b9f6-4bb0-844a-3e0ed82736ca',
#     'date': '08-05-2021',
#     'available_capacity': 44,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'ad335cb1-7b57-4255-b91e-4598c31470cb',
#     'date': '10-05-2021',
#     'available_capacity': 46,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 8785,
#   'name': 'CGHS Dispensary South Avenue',
#   'address': '153, South Avenue , New Delhi-11',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '8e8451bb-a88e-4ee9-96a5-38c35880d7ee',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'a236f658-76dc-46e9-b3c3-abf91e75370a',
#     'date': '08-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '5de98904-cb39-4568-90cd-dbff15aa679c',
#     'date': '10-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 8811,
#   'name': 'MCW Babar Road NDMC PHC',
#   'address': '42, Dispensary Complex, 1st Floor, Babar Road, New Delhi 110001',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '38a9755b-3cbb-4966-a568-bd44edb3e4cd',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': 'bdd75a0d-7216-4d2c-8ee6-30240c73923d',
#     'date': '08-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '6be5562d-d902-4cdc-9793-70107ed17f81',
#     'date': '10-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 8815,
#   'name': 'MCW Reading Road NDMC PHC',
#   'address': 'Old Auto Workshop Building, Mandir Marg, New Delhi -110001',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '815242fe-d8f9-41bb-84c5-b5ba419f2d01',
#     'date': '06-05-2021',
#     'available_capacity': 38,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '87d194e8-6c31-4ffc-ae96-a657dc41d57f',
#     'date': '08-05-2021',
#     'available_capacity': 40,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']},
#    {'session_id': '0fb4fe33-17ad-400d-9804-bae9ac997011',
#     'date': '10-05-2021',
#     'available_capacity': 50,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]},
#  {'center_id': 627344,
#   'name': 'DGHC Supreme Court',
#   'address': 'DGHC Supreme Court Complex, Bhagwan Das Road',
#   'state_name': 'Delhi',
#   'district_name': 'New Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110001,
#   'lat': 28,
#   'long': 77,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'fee_type': 'Free',
#   'sessions': [{'session_id': '6189b31a-7880-4446-afcd-ed176d35e8d3',
#     'date': '06-05-2021',
#     'available_capacity': 0,
#     'min_age_limit': 45,
#     'vaccine': 'COVISHIELD',
#     'slots': ['09:00AM-11:00AM',
#      '11:00AM-01:00PM',
#      '01:00PM-03:00PM',
#      '03:00PM-05:00PM']}]}]

# %% [markdown]
# final_data = str(d['centers']).replace('[','').replace(']','')

# %%
temp = str(d['centers']).replace("'","\"")

# %%
final_data = json.loads(temp)

# %%
final_data[0]#["sessions"]["available_capacity"]
# Out:
# {'center_id': 662447,
#  'name': 'ICGS Delhi',
#  'address': 'MI Room, National Stadium Complex, New Delhi, 110001',
#  'state_name': 'Delhi',
#  'district_name': 'New Delhi',
#  'block_name': 'Not Applicable',
#  'pincode': 110001,
#  'lat': 28,
#  'long': 77,
#  'from': '09:00:00',
#  'to': '17:00:00',
#  'fee_type': 'Free',
#  'sessions': [{'session_id': '056423a7-4c71-49ae-b91e-6e09086c3076',
#    'date': '04-05-2021',
#    'available_capacity': 0,
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-05:00PM']},
#   {'session_id': 'b7440b34-cafe-4fe4-8792-75b255e0eaae',
#    'date': '05-05-2021',
#    'available_capacity': 0,
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-05:00PM']},
#   {'session_id': '29f24327-baee-4fcf-b69b-870995de00f5',
#    'date': '06-05-2021',
#    'available_capacity': 0,
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-05:00PM']},
#   {'session_id': '1f7b65da-6952-4ee0-aca0-1d5ef62847f8',
#    'date': '07-05-2021',
#    'available_capacity': 0,
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-05:00PM']},
#   {'session_id': 'fdfcdde1-cde9-479d-89b2-ea1ccca799fa',
#    'date': '08-05-2021',
#    'available_capacity': 0,
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-05:00PM']},
#   {'session_id': '4e2b7594-d2e1-4d62-ba2d-caf1e1c819be',
#    'date': '10-05-2021',
#    'available_capacity': 0,
#    'min_age_limit': 45,
#    'vaccine': 'COVISHIELD',
#    'slots': ['09:00AM-11:00AM',
#     '11:00AM-01:00PM',
#     '01:00PM-03:00PM',
#     '03:00PM-05:00PM']}]}

# %%
final_data["sessions"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-28506670833b> in <module>
# ----> 1 final_data["sessions"]
#
# TypeError: list indices must be integers or slices, not str
